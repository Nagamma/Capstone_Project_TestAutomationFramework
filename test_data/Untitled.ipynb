# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
mysql_engine = create_engine(f'mysql+pymysql://root:admin%401990@localhost:3306/Feb2026Retaildwh').connect()
print(mysql_engine)

# %%
sql_query = "select * from stag_suplier"
df_actual = pd.read_sql(sql_query,mysql_engine)
df_actual
# Out:
#    supplier_id         supplier_name    contact_name  \
# 0            1      ABC Distributors        John Doe
# 1            2     Global Goods Inc.      Jane Smith
# 2            3   GreenTech Solutions  Robert Johnson
# 3            4              EuroWare     Emily White
# 4            5      Pacific Products   Michael Brown
# 5            6     Fresh Produce Co.    Sarah Taylor
# 6            7  TechCore Electronics       David Lee
# 7            8       HanYang Trading      Laura King
# 8            9         Indo Supplies  James Williams
# 9           10         LatAm Imports   Olivia Harris
#
#                        contact_email     contact_phone    country  rating  \
# 0                johndoe@abcdist.com       +1-555-0100        USA     4.8
# 1          janesmith@globalgoods.com       +1-555-0200     Canada     4.3
# 2       robert.johnson@greentech.com  +44-20-7946-0100         UK     4.6
# 3          emily.white@euro-ware.com  +49-30-9876-5432    Germany     4.2
# ...

# %%
df_expected = pd.read_json("supplier_data.json")
df_expected
# Out:
#    supplier_id         supplier_name    contact_name  \
# 0            1      ABC Distributors        John Doe
# 1            2     Global Goods Inc.      Jane Smith
# 2            3   GreenTech Solutions  Robert Johnson
# 3            4              EuroWare     Emily White
# 4            5      Pacific Products   Michael Brown
# 5            6     Fresh Produce Co.    Sarah Taylor
# 6            7  TechCore Electronics       David Lee
# 7            8       HanYang Trading      Laura King
# 8            9         Indo Supplies  James Williams
# 9           10         LatAm Imports   Olivia Harris
#
#                        contact_email     contact_phone    country  rating  \
# 0                johndoe@abcdist.com       +1-555-0100        USA     4.8
# 1          janesmith@globalgoods.com       +1-555-0200     Canada     4.3
# 2       robert.johnson@greentech.com  +44-20-7946-0100         UK     4.6
# 3          emily.white@euro-ware.com  +49-30-9876-5432    Germany     4.2
# ...

# %%
df_expected[~df_expected.apply(tuple,axis=1).isin(df_actual.apply(tuple,axis=1))]
# Out:
#    supplier_id  supplier_name   contact_name                   contact_email  \
# 9           10  LatAm Imports  Olivia Harris  olivia.harris@latamimports.com
#
#       contact_phone country  rating last_order_date
# 9  +52-55-2345-6789  Mexico     4.8      2024-11-20

# %%
df_actual[~df_actual.apply(tuple,axis=1).isin(df_expected.apply(tuple,axis=1))]
# Out:
#    supplier_id  supplier_name   contact_name                   contact_email  \
# 9           10  LatAm Imports  Olivia Harris  olivia.harris@latamimports.com
#
#       contact_phone country  rating last_order_date
# 9  +52-55-2345-6789  Mexico     4.5      2024-11-20
